# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_cc = pd.read_csv('CCFraud.csv')
df_cc
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
#lets check for some missing values
df_cc.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
#very nice no missing values , lets check for the data info
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
#cool then ,  so the main thing here is the mode of transsaction or payment ,so lets check for that 
df_cc.type.value_counts()
# Out:
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: type, dtype: int64

# %%
#now lets check for correletion
correletion =df_cc.corr()
correletion
# Out:
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.022373      -0.010058       -0.010299
# amount          0.022373  1.000000      -0.002762       -0.007861
# oldbalanceOrg  -0.010058 -0.002762       1.000000        0.998803
# newbalanceOrig -0.010299 -0.007861       0.998803        1.000000
# oldbalanceDest  0.027665  0.294137       0.066243        0.067812
# newbalanceDest  0.025888  0.459304       0.042029        0.041837
# isFraud         0.031578  0.076688       0.010154       -0.008148
# isFlaggedFraud  0.003277  0.012295       0.003835        0.003776
#
#                 oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# step                  0.027665        0.025888  0.031578        0.003277
# amount                0.294137        0.459304  0.076688        0.012295
# oldbalanceOrg         0.066243        0.042029  0.010154        0.003835
# newbalanceOrig        0.067812        0.041837 -0.008148        0.003776
# ...

# %%
plt.figure(figsize=(15,8))

sns.heatmap(correletion,annot=True)
# Out:
# <AxesSubplot:>

# %%
print(correletion['isFraud'].sort_values(ascending=False))
# Out:
# isFraud           1.000000
# amount            0.076688
# isFlaggedFraud    0.044109
# step              0.031578
# oldbalanceOrg     0.010154
# newbalanceDest    0.000535
# oldbalanceDest   -0.005885
# newbalanceOrig   -0.008148
# Name: isFraud, dtype: float64

# %%
fr_counts = df_cc['isFraud'].value_counts()
fr_counts
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
fr_ptype =df_cc.groupby(by=df_cc['type'])['isFraud'].sum()
fr_ptype
# Out:
# type
# CASH_IN        0
# CASH_OUT    4116
# DEBIT          0
# PAYMENT        0
# TRANSFER    4097
# Name: isFraud, dtype: int64

# %%
#so from above we can clearly see that the fraud paymnets are made under the type cashouts and transfer

# %%
#so now lets see h,ow much amount of fraud has been made
df_amount = df_cc.loc[df_cc['isFraud']==1]
df_amount['Fraud_amount']=df_amount['oldbalanceOrg']-df_amount['newbalanceOrig']
sortam = df_amount.sort_values(by=['Fraud_amount'],ascending=False)
sortam
# Out:
# <ipython-input-13-3a1f88f0f3f4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_amount['Fraud_amount']=df_amount['oldbalanceOrg']-df_amount['newbalanceOrig']
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 5563707   387  TRANSFER  10000000.00  C1421664654    34892193.09
# 6357390   710  TRANSFER  10000000.00   C671111468    37418265.31
# 6266405   617  TRANSFER  10000000.00   C794290057    42542664.27
# 6010857   444  TRANSFER  10000000.00  C1295280435    23752520.60
# 5563723   387  TRANSFER  10000000.00  C1074619527    19110884.44
# ...       ...       ...          ...          ...            ...
# 2242699   186  CASH_OUT    229909.57   C260366436           0.00
# ...

# %%
df_amount['Fraud_amount'].value_counts()
# Out:
# 10000000.00    262
# 0.00            57
# 10000000.00     12
# 10000000.00      5
# 429257.45        4
#               ...
# 75956.47         1
# 4499.08          1
# 4505.60          1
# 994453.20        1
# 42062.82         1
# Name: Fraud_amount, Length: 3943, dtype: int64

# %%
df_cc
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
sns.histplot(data=df_cc,x='type')
# Out:
# <AxesSubplot:xlabel='type', ylabel='Count'>

# %%
#here i m gonna see the variations of the data thru box pplot
sns.boxplot(data=df_cc,x='amount')
# Out:
# <AxesSubplot:xlabel='amount'>

# %%
sns.boxplot(data=df_cc,x='step')
# Out:
# <AxesSubplot:xlabel='step'>

# %%
sns.boxplot(data=df_cc,x='isFraud',y='amount')
# Out:
# <AxesSubplot:xlabel='isFraud', ylabel='amount'>

# %%
#as we see from above data spread i see that there are so much of outliers in the data ,as of now i am not doing any scaling to the data
#so now lets build model and see how it goes 

df_cc
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
# from data i am dropping the coloum 'anmeOrig' and 'nameDest' as i wont use them in my model training

df_model = df_cc.drop(['nameOrig','nameDest'],axis=1,inplace=False)
df_model
# Out:
#          step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1   PAYMENT     9839.64      170136.00       160296.36
# 1           1   PAYMENT     1864.28       21249.00        19384.72
# 2           1  TRANSFER      181.00         181.00            0.00
# 3           1  CASH_OUT      181.00         181.00            0.00
# 4           1   PAYMENT    11668.14       41554.00        29885.86
# ...       ...       ...         ...            ...             ...
# 6362615   743  CASH_OUT   339682.13      339682.13            0.00
# 6362616   743  TRANSFER  6311409.28     6311409.28            0.00
# 6362617   743  CASH_OUT  6311409.28     6311409.28            0.00
# 6362618   743  TRANSFER   850002.52      850002.52            0.00
# 6362619   743  CASH_OUT   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                  0.00            0.00        0               0
# ...

# %% [markdown]
# ### Labelencoding for categorical features

# %%
#here i am going to do labelencoding to the type feature

from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
df_model['type']=lab.fit_transform(df_model['type'])

# %%
df_model
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64      170136.00       160296.36
# 1           1     3     1864.28       21249.00        19384.72
# 2           1     4      181.00         181.00            0.00
# 3           1     1      181.00         181.00            0.00
# 4           1     3    11668.14       41554.00        29885.86
# ...       ...   ...         ...            ...             ...
# 6362615   743     1   339682.13      339682.13            0.00
# 6362616   743     4  6311409.28     6311409.28            0.00
# 6362617   743     1  6311409.28     6311409.28            0.00
# 6362618   743     4   850002.52      850002.52            0.00
# 6362619   743     1   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                  0.00            0.00        0               0
# 1                  0.00            0.00        0               0
# ...

# %% [markdown]
# ### modelelling using ml alogs

# %%
X=df_model.drop('isFraud',axis = 1)
y=df_model['isFraud']

X
# Out:
#          step  type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1     3     9839.64      170136.00       160296.36
# 1           1     3     1864.28       21249.00        19384.72
# 2           1     4      181.00         181.00            0.00
# 3           1     1      181.00         181.00            0.00
# 4           1     3    11668.14       41554.00        29885.86
# ...       ...   ...         ...            ...             ...
# 6362615   743     1   339682.13      339682.13            0.00
# 6362616   743     4  6311409.28     6311409.28            0.00
# 6362617   743     1  6311409.28     6311409.28            0.00
# 6362618   743     4   850002.52      850002.52            0.00
# 6362619   743     1   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest  isFlaggedFraud
# 0                  0.00            0.00               0
# 1                  0.00            0.00               0
# ...

# %%
y
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 6362615    1
# 6362616    1
# 6362617    1
# 6362618    1
# 6362619    1
# Name: isFraud, Length: 6362620, dtype: int64

# %%
#lets split the data for train and test data

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=30)

# %% [markdown]
# ### LogisticRegression model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lg_reg = LogisticRegression()
lg_reg.fit(X_train,y_train)

lg_pred = lg_reg.predict(X_test)

print('the prediction has an acc_score as : {:0.5f}'.format(accuracy_score(y_test,lg_pred)))
# Out:
# the prediction has an acc_score as : 0.99823
